# %%
! conda install -y gdown

# %%
# !gdown --id 1sThJ2PjZvdbmmpkWRDl_cu5FruGETqNZ

# %%
# !apt-get install unrar
# !unrar x "./ML_Data G1.rar"

# %%
# !rm -rf "./ML_Data G1.rar"

# %%
import librosa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import csv
# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
# !pip install surfboard --user

# %%
# !rm -rf "./ML_Data G1/Lori/89.mp3"
# !rm -rf "./ML_Data G1/Gilaki/11.mp3"
# !rm -rf "./ML_Data G1/Bandari/22.mp3"
# !rm -rf "./ML_Data G1/Torki/104.mp3"
# !rm -rf "./ML_Data G1/Lori/156.mp3"

# %%
genres = 'Lori Kordi Torki Bandari Gilaki'.split()
for g in genres:
    # for filename in os.listdir(f'./dataset/ML_Data G1/{g}'):
    _, __,files = next(os.walk(f'./ML_Data G1/{g}'))
    for filename in files:
     
        songname = f'./ML_Data G1/{g}/{filename}'
        sound = Waveform(path=songname)
        main1.append(extract_features([sound],
                                              ['mfcc', 'log_melspec'],
                                              ['mean', 'std', 'skewness',
                                               'kurtosis']))
        main2.append(extract_features([sound], ['rms',  'chroma_stft' ,
                                                        'zerocrossing', 'ppe'],
                                               ['mean', 'std']))
        main3.append(extract_features([sound], ['magnitude_spectrum'],
                                              ['mean', 'std', 'skewness',
                                               'kurtosis', 'q3_q1_range']))
        main4.append(extract_features([sound], ['shannon_entropy_slidingwindow'],
                                      ['mean', 'std', 'skewness', 'kurtosis']))

main1 = pd.concat(main1)
main2 = pd.concat(main2)
main3 = pd.concat(main3)
main4 = pd.concat(main4)

main1.to_csv("melMFCC.csv")
main2.to_csv("zcrossRMS.csv")
main3.to_csv("spectrum.csv")
main4.to_csv("cwt.csv")
